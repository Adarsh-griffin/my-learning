# %%
import sys
print(sys.executable)
# Out:
# C:\Users\heman\OneDrive\Desktop\hackathon\langchainupdated\.venv\Scripts\python.exe

# %%
import langchain

print(langchain.__version__)
print(langchain.__file__)
# Out:
# 1.3.12
# C:\Users\heman\OneDrive\Desktop\hackathon\langchainupdated\.venv\Lib\site-packages\langchain\__init__.py

# %%
from langchain.agents import create_agent

print("Success!")
# Out:
# Success!
