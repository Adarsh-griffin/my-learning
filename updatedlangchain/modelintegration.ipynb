# %%
import langchain
langchain.__version__
# Out:
# '1.3.12'

# %%
import os
import langchain
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI-API_KEY"]=os.getenv("openai_api_key")
os.environ["GROQ_API_KEY"]=os.getenv("groq_api_key")
os.environ["GOOGLE_API_KEY"]=os.getenv("google_api_key")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("llama-3.3-70b-versatile" , model_provider="groq")
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.12'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x00000167125FF490>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000167125FFE10>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
response=model.invoke("hello how are you?")
response
print(response.content)
# Out:
# Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you. How can I help you today? Is there something specific you'd like to talk about or ask? I'm here to help.

# %%
model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots are renowned for their ability to mimic human speech, and it\'s a truly fascinating phenomenon rooted in a combination of their social nature, unique biology, and intelligence. Here\'s a breakdown of the key reasons:\n\n1.  **They are Highly Social Flock Animals:**\n    *   **Need to Belong:** In the wild, parrots live in large, complex social groups (flocks). Communication is vital for their survival and social cohesion. They use a wide range of calls for alarm, contact, identification, and mating.\n    *   **Fitting In:** When a parrot lives with humans, it naturally views us as its flock. Mimicking our sounds is their way of trying to communicate, bond, and be an accepted member of *our* flock. It\'s a social strategy.\n\n2.  **They Are Vocal Learners (A Rare Trait):**\n    *   **Adaptability:** Unlike many animals that are born with a fixed set of vocalizations, parrots are "vocal learners." This means they can learn new sounds throughout their lives and adapt their calls to their environment or social group. This ability is shared by only a few other animal groups, like songbirds, hummingbirds, whales, dolphins, and bats.\n    *   **Cultural Transmission:** In the wild, this allows young parrots to learn the specific calls of their parents or flock, and even allows flocks to develop unique "dialects." This strong drive to imitate extends to human speech when they are exposed to it regularly.\n\n3.  **Unique Vocal Anatomy:**\n    *   **The Syrinx:** Parrots possess a highly developed and flexible syrinx (their voice box), which allows them to produce a wide range of sounds, pitches, and tones.\n    *   **Tongue and Beak:** They also have thick, muscular tongues (unlike many birds) and precise control over their beaks, which aids in articulating sounds that resemble human speech.\n\n4.  **Intelligence and Cognitive Abilities:**\n    *   **Problem-Solving:** Parrots are highly intelligent birds, known for their problem-solving skills, memory, and ability to understand cause and effect.\n    *   **Contextual Understanding:** While they don\'t "understand" human language in the same way we do, they can learn to associate words and phrases with specific contexts, actions, or objects. For example, a parrot might learn to say "hello" when someone enters the room, or "want a cracker?" when it sees a treat. This demonstrates a level of cognitive processing beyond simple mimicry.\n\n5.  **Reinforcement and Motivation:**\n    *   **Attention and Interaction:** When a parrot says something and gets a positive reaction from its human "flock" (attention, praise, a treat, or even laughter), it reinforces the behavior. They learn that certain sounds lead to desired outcomes and enjoy the interaction.\n\nIn essence, a parrot\'s "talking" is a sophisticated form of social communication, driven by its innate desire to connect with its flock, its remarkable capacity for vocal learning, and its unique biological equipment. It\'s a testament to their complex social intelligence.'

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content="Artificial Intelligence (AI) fundamentally involves programming machines to simulate and execute human-like intelligence, enabling them to learn, reason, perceive, and make decisions. This expansive field encompasses various sub-disciplines like machine learning, deep learning, natural language processing, and computer vision. At its core, AI systems analyze vast datasets using complex algorithms to identify patterns, predict outcomes, and automate sophisticated tasks, often surpassing human efficiency and accuracy in specific domains. From the personalized recommendations that shape our online experiences to the voice assistants in our homes, AI is deeply integrated into daily life. Its transformative power is evident across industries, revolutionizing healthcare through advanced diagnostics and drug discovery, optimizing logistics and manufacturing with predictive analytics, and enhancing finance with fraud detection and algorithmic trading. The relentless progress in AI promises to unlock solutions to some of humanity's most pressing challenges, fostering unprecedented innovation. Yet, this rapid evolution also necessitates critical discourse on ethical implications, potential biases, data privacy, and the societal impact on employment, underscoring the importance of responsible development and thoughtful governance to ensure AI serves humanity's best interests.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4ce8-af58-72f2-b710-af6a71951e4e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 891, 'total_tokens': 904, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 671}})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# Artificial Intelligence (AI) represents the ambitious endeavor to imbue machines with human-like cognitive abilities, enabling them to perceive, reason, learn, and problem-solve. At its| core, AI seeks to create intelligent agents capable of understanding their environment and taking actions that maximize their chances of achieving specific goals. This vast field encompasses various sub-disciplines, most notably Machine Learning (ML), where algorithms learn from data without| explicit programming, and Deep Learning (DL), which utilizes neural networks inspired by the human brain to process complex patterns.
#
# The applications of AI are rapidly expanding across every sector imaginable. In healthcare, AI assists in disease diagnosis, drug discovery,| and personalized treatment plans. Finance leverages AI for fraud detection, algorithmic trading, and risk assessment. From powering recommendation systems on streaming platforms to enabling self-driving cars and sophisticated robotics in manufacturing, AI is fundamentally reshaping industries and daily life. While| promising unparalleled advancements in efficiency, innovation, and problem-solving for humanity's grand challenges, AI also introduces complex ethical considerations regarding data privacy, algorithmic bias, job displacement, and the ultimate control of increasingly autonomous systems. AI is not merely| a technological trend; it is a transformative force defining the trajectory of human civilization.||

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content="Parrots are renowned for their stunning, vibrant plumage, and there isn't just one reason for this dazzling display, but rather a fascinating combination of evolutionary advantages:\n\n1.  **Camouflage (Surprisingly!)**\n    While counter-intuitive to us, bright colors can be excellent camouflage in their natural habitats, which are often dense, tropical rainforests.\n    *   **Green parrots** blend seamlessly with the lush canopy of leaves.\n    *   **Red and yellow patches** can mimic the vibrant flowers and fruits found in the forest.\n    *   **Blue feathers** can blend with dappled sunlight filtering through the trees or the sky above.\n    *   The constantly shifting light and shadow in a dense forest can make even the brightest bird disappear.\n\n2.  **Sexual Selection and Mating**\n    This is a primary driver for vibrant colors in many bird species.\n    *   **Signaling Fitness:** Bright, well-maintained feathers are a strong indicator of a bird's health, good foraging ability, and genetic quality. A bird that can afford to produce and maintain such brilliant colors despite the energy cost and potential increased predator visibility is likely a strong, healthy mate.\n    *   **Attracting Mates:** Females often choose males with the most vibrant and elaborate plumage, as this suggests they will pass on good genes to their offspring.\n\n3.  **Species Recognition**\n    In areas where multiple parrot species coexist, distinct color patterns help individual birds quickly identify members of their own species. This prevents hybridization and ensures they find appropriate partners for mating and flocking.\n\n4.  **Social Signaling and Flock Cohesion**\n    Within a flock, colors can play a role in communication:\n    *   **Hierarchy:** Brighter individuals might signify dominance.\n    *   **Mood:** Feather displays can communicate excitement, aggression, or distress.\n    *   **Flock Movement:** Bright colors can help keep large flocks together, especially during flight through dense vegetation, making it easier to follow leaders.\n\n5.  **How the Colors are Produced:**\n    The vibrant colors themselves come from two main sources:\n    *   **Pigments:**\n        *   **Carotenoids:** These are pigments obtained from the parrot's diet (fruits, vegetables, seeds). They produce yellows, reds, and oranges. A diet rich in carotenoids contributes to brighter, healthier colors.\n        *   **Psittacofulvins:** These are unique to parrots and are responsible for many of their bright red, orange, and yellow hues. Unlike carotenoids, parrots synthesize these pigments themselves.\n    *   **Structural Colors:** Blues, greens, and iridescent colors are not due to pigments but rather to the microscopic structure of the feathers. These structures scatter light in specific ways, reflecting certain wavelengths (like blue) while absorbing others. When combined with yellow pigment, structural blue can produce green.\n\nIn summary, the colorful feathers of parrots are a beautiful example of evolution at work, serving multiple purposes from blending into their environment to attracting mates and communicating within their complex social structures.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4d06-3316-73a3-acb1-c42b576e1d9a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 1792, 'total_tokens': 1800, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1154}})

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# Parrots are renowned for their stunning, vibrant plumage, and their colorful feathers serve several important evolutionary purposes|:
#
# 1.  **Sexual Selection and Mate Attraction:** This is often the primary driver for elaborate coloration in many bird species.
#     *   **Signaling Fitness:** Bright, well-maintained feathers are a strong indicator of a parrot|'s health, vigor, and ability to find food and avoid predators. A parrot that can invest resources into producing vivid pigments and keeping its feathers clean and intact is likely a good genetic candidate.
#     *   **Mate Choice:** Par|rots (both males and females, as many parrot species are monomorphic, meaning both sexes look similar) use these visual cues to choose the best mates. Brighter, more complex patterns can be more attractive.
#
# 2.  **Species Recognition:**| In biodiverse tropical environments where many similar-looking species might coexist, distinct color patterns help parrots quickly identify members of their own species. This prevents hybridization and ensures successful breeding within their own kind.
#
# 3.  **Camouflage (Counter|-intuitive but true!):** While bright colors might seem to make a parrot stand out, in the dappled light and vibrant foliage of a tropical rainforest, they can actually provide excellent camouflage.
#     *   **Broken Outline:** Pat|ches of bright green, red, blue, and yellow can break up the bird's silhouette, making it harder for predators (like hawks or monkeys) to spot them against a background of green leaves, colorful fruits, and flowers.
#     *|   **Dappled Light:** The constantly shifting light and shadow in a dense canopy can make a brightly colored bird blend surprisingly well.
#
# 4.  **Signaling Social Status and Dominance:** Within a flock, more vibrant or well-maintained plumage| might signal a higher social status or dominance, which can be important for access to resources or mates.
#
# 5.  **Diet and Pigmentation:** The colors themselves are produced by different types of pigments:
#     *   **Carotenoids:**| Many reds, yellows, and oranges come from carotenoid pigments, which parrots must obtain through their diet (e.g., from fruits, seeds, and vegetables). The ability to acquire and process these pigments is a sign of good foraging skills| and health.
#     *   **Psittacofulvins:** Parrots are unique in their ability to synthesize their own red, orange, and yellow pigments called psittacofulvins. This internal production requires metabolic energy,| so a parrot with vibrant psittacofulvin colors is signaling its robust metabolic health.
#     *   **Melanins:** Blacks, browns, and grays are produced by melanin pigments, which also contribute to feather strength and durability.
# |    *   **Structural Colors:** Blues and some greens are often "structural colors," created by the way light interacts with the microscopic structure of the feathers, rather than by pigments alone.
#
# In summary, the dazzling array of colors on a parrot's| feathers is not just for show; it's a sophisticated evolutionary adaptation that plays a crucial role in their survival, reproduction, and social interactions within their complex natural environments.||

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots, with their dazzling array of colors, are a prime example of how evolution shapes species for survival and reproduction. Their vibrant plumage is a result of several interconnected factors:\n\n1.  **Sexual Selection and Mate Attraction:**\n    *   **Signaling Health and Fitness:** Brighter, more vibrant colors often signal a parrot's good health, strong immune system, and ability to find nutritious food. A parrot that can maintain brilliant plumage despite the demands of its environment is likely a strong, viable mate.\n    *   **Display:** During courtship rituals, parrots often puff up their feathers, display specific color patches, and perform dances to attract a mate. The intensity and beauty of their colors play a crucial role in these displays.\n\n2.  **Species Recognition:**\n    *   In diverse tropical environments where many bird species (including different parrot species) coexist, distinct color patterns help parrots quickly identify members of their own species. This is vital for finding appropriate mates, avoiding hybridization, and maintaining flock cohesion.\n\n3.  **Camouflage (Counter-intuitive but True!):**\n    *   While they seem incredibly bright to us, parrots often live in dense, dappled tropical rainforests. Against a backdrop of green leaves, colorful fruits, flowers, dappled sunlight, and deep shadows, their bright colors can actually be surprisingly effective camouflage.\n    *   **Disruptive Coloration:** Patches of bright red, blue, green, and yellow can break up the bird's outline, making it harder for predators (like birds of prey or snakes) to spot them against the complex, varied background of the forest canopy, especially when they are still.\n\n4.  **Social Signaling:**\n    *   Within a flock, colors can communicate various messages, such as dominance, age, or readiness to breed. For highly social animals like parrots, effective communication within the group is crucial.\n\n---\n\n**How Parrots Get Their Colors (The Science):**\n\nParrot colors come from two main sources:\n\n1.  **Pigments:**\n    *   **Psittacofulvins:** These are unique pigments found *only* in parrots, responsible for their brilliant yellows, oranges, and reds. Parrots can synthesize these pigments themselves.\n    *   **Carotenoids:** These pigments produce yellows, oranges, and reds, but unlike psittacofulvins, parrots obtain them through their diet (e.g., from fruits, vegetables, and seeds). The availability of these dietary pigments can influence the vibrancy of their feathers.\n    *   **Melanins:** These pigments produce blacks, browns, grays, and some muted yellows/reds. They also contribute to feather strength.\n\n2.  **Structural Coloration:**\n    *   Many of the blues, greens, and iridescent hues in parrots are not caused by pigments but by the microscopic structure of the feathers themselves. These tiny structures scatter and reflect specific wavelengths of light.\n    *   For example, blue is almost always a structural color. Green is often achieved by a combination of structural blue and yellow pigments.\n\nIn summary, the vibrant colors of parrots are a beautiful evolutionary adaptation, serving multiple critical roles from attracting mates and recognizing their own kind to providing surprising camouflage within their complex habitats.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4d09-eb88-7713-a867-3312e5197638-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 1935, 'total_tokens': 1943, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1259}}),
#  AIMessage(content='Airplanes fly thanks to a fascinating interplay of four fundamental forces: **lift, thrust, drag,** and **weight**. For an airplane to fly level, lift must equal weight, and thrust must equal drag. To take off, lift and thrust must be greater.\n\nHere\'s a breakdown of how each force contributes:\n\n1.  **Lift (The Upward Force):** This is the most crucial force for keeping a plane in the air. It\'s primarily generated by the wings, which are shaped like an **airfoil**.\n    *   **Airfoil Shape:** A wing has a curved top surface and a flatter bottom surface. As air flows over the wing:\n        *   **Bernoulli\'s Principle:** The air traveling over the curved top surface has to travel a longer distance and therefore speeds up. According to Bernoulli\'s principle, faster-moving air has lower pressure.\n        *   **Newton\'s Third Law / Angle of Attack:** The air traveling under the flatter bottom surface is slowed down and creates higher pressure. Also, the wing is usually tilted slightly upwards (called the "angle of attack"), which deflects air downwards. According to Newton\'s Third Law, for every action, there is an equal and opposite reaction. Pushing air down creates an upward force (lift) on the wing.\n    *   **In essence:** The combination of lower pressure above the wing and higher pressure below it (along with the wing pushing air downwards) creates an upward force that "lifts" the plane.\n\n2.  **Thrust (The Forward Force):** This is the force that propels the airplane forward through the air, overcoming drag. It\'s generated by the engines:\n    *   **Jet Engines:** These engines suck in air, compress it, mix it with fuel, ignite it, and then blast the hot, high-pressure exhaust gases out the back. This powerful expulsion of gas creates a forward thrust (again, Newton\'s Third Law).\n    *   **Propeller Engines:** Propellers are essentially rotating wings. As they spin, they cut through the air, creating a pressure difference that pulls the plane forward by pushing air backward.\n    *   **In essence:** Engines provide the power to move the plane fast enough to generate sufficient lift.\n\n3.  **Drag (The Resisting Force):** This is the resistance an object experiences when moving through a fluid (in this case, air). It acts opposite to the direction of motion.\n    *   **Aerodynamic Design:** Airplane engineers design planes to be as streamlined and smooth as possible to minimize drag. Every part of the plane, from the nose to the tail, is shaped to allow air to flow over it with minimal resistance.\n    *   **In essence:** Drag is the enemy of speed and efficiency, so minimizing it is key.\n\n4.  **Weight (The Downward Force):** This is simply the force of gravity pulling the airplane down towards the Earth.\n    *   **Overcoming Weight:** For an airplane to fly, the lift generated by its wings must be equal to or greater than its total weight (including the plane itself, fuel, passengers, and cargo).\n    *   **In essence:** Lift must constantly counteract weight to keep the plane airborne.\n\n**How They Work Together (The Flight Process):**\n\n1.  **Takeoff:** The engines generate maximum thrust, accelerating the plane down the runway. As speed increases, the wings generate more and more lift. When lift becomes greater than weight, the plane takes off.\n2.  **Climb:** The pilot maintains a high angle of attack and high thrust to continue gaining altitude.\n3.  **Cruise:** At cruising altitude, the pilot reduces thrust to maintain a constant speed. Lift equals weight, and thrust equals drag, allowing for stable, level flight.\n4.  **Descent:** The pilot reduces thrust and/or reduces lift (by adjusting flaps or angle of attack) to allow the plane to lose altitude.\n5.  **Landing:** Flaps are extended on the wings to increase lift at lower speeds and increase drag to slow the plane down for a safe landing.\n\nIn summary, airplanes fly because their engines generate enough **thrust** to move t ...
#  AIMessage(content='**Quantum computing** is a new type of computing that harnesses the principles of quantum mechanics to solve complex problems that are beyond the capabilities of classical computers.\n\nHere\'s a breakdown of what that means:\n\n## The Core Difference: Qubits vs. Bits\n\nClassical computers, like your laptop or smartphone, store information in **bits**. A bit can be in one of two states: **0** or **1**.\n\nQuantum computers use **qubits**. Qubits are fundamentally different:\n\n1.  **Superposition:** A qubit can be 0, 1, or **both 0 and 1 simultaneously**. Imagine a spinning coin: it\'s neither heads nor tails until it lands. A qubit in superposition is like that spinning coin, representing multiple possibilities at once. This allows quantum computers to process vast amounts of information in parallel.\n\n2.  **Entanglement:** This is a bizarre and powerful quantum phenomenon where two or more qubits become linked in such a way that they share the same fate, no matter how far apart they are. If you measure the state of one entangled qubit, you instantly know the state of the other(s). This correlation allows quantum computers to perform incredibly complex calculations and discover relationships between data points that would be impossible for classical machines.\n\n3.  **Interference:** Quantum states can constructively or destructively interfere with each other, similar to how waves interact. Quantum algorithms are designed to amplify the probability of getting the correct answer and diminish the probability of getting incorrect ones.\n\n## How Quantum Computers Work (Simply)\n\nInstead of using logic gates on bits, quantum computers use **quantum gates** to manipulate qubits. These gates operate on qubits in superposition and entanglement, allowing them to explore many possible solutions simultaneously. When the computation is complete, the qubits\' states are measured, collapsing their superposition into a definite 0 or 1, which provides the answer. Because of the probabilistic nature, this process often needs to be repeated many times to get a reliable result.\n\n## Why is it Powerful? (Potential Applications)\n\nQuantum computers aren\'t designed to replace classical computers for everyday tasks like browsing the internet or word processing. Instead, they excel at specific types of problems that involve immense complexity and many variables.\n\nSome key areas where quantum computing could have a revolutionary impact include:\n\n1.  **Drug Discovery & Materials Science:** Simulating molecular interactions with unprecedented accuracy, leading to the development of new drugs, catalysts, and materials with novel properties (e.g., superconductors, more efficient batteries).\n2.  **Cryptography:** Breaking current encryption methods (like RSA) with algorithms like Shor\'s algorithm, but also creating new, unhackable quantum-safe encryption methods.\n3.  **Optimization:** Solving complex optimization problems in logistics, finance, manufacturing, and supply chains to find the most efficient solutions (e.g., optimizing delivery routes, financial portfolios, factory schedules).\n4.  **Artificial Intelligence & Machine Learning:** Enhancing AI capabilities through quantum machine learning algorithms that can process larger datasets and identify more complex patterns.\n5.  **Financial Modeling:** Creating more accurate and sophisticated financial models for risk assessment, fraud detection, and market prediction.\n\n## Challenges and Current Status\n\nQuantum computing is still in its early stages of development. Key challenges include:\n\n*   **Decoherence:** Qubits are extremely fragile and lose their quantum properties (superposition and entanglement) very easily due to environmental noise (heat, vibration, electromagnetic fields). This requires extreme isolation, often at super-cold temperatures.\n*   **Error Correction:** Due to decoherence, errors are common. Building robust error correction mechanisms is i ...
